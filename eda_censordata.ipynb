# %%
import pandas as pd
data=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data')

# %%
data.head()
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
data.shape
# Out:
# (32560, 15)

# %%
data.tail()
# Out:
#        39      State-gov   77516    Bachelors   13        Never-married  \
# 32555  27        Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40        Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58        Private  151910      HS-grad    9              Widowed
# 32558  22        Private  201490      HS-grad    9        Never-married
# 32559  52   Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
#              Adm-clerical  Not-in-family   White     Male   2174   0   40  \
# 32555        Tech-support           Wife   White   Female      0   0   38
# 32556   Machine-op-inspct        Husband   White     Male      0   0   40
# 32557        Adm-clerical      Unmarried   White   Female      0   0   40
# 32558        Adm-clerical      Own-child   White     Male      0   0   20
# 32559     Exec-managerial           Wife   White   Female  15024   0   40
#
#         United-States   <=50K
# 32555   United-States   <=50K
# ...

# %%
data.sample(10)
# Out:
#        39          State-gov   77516      Bachelors   13        Never-married  \
# 6640   19            Private  131615        HS-grad    9        Never-married
# 30578  17            Private   27415           11th    7        Never-married
# 5978   37       Self-emp-inc  107164           10th    6        Never-married
# 2213   64   Self-emp-not-inc  177825        HS-grad    9        Never-married
# 17228  41   Self-emp-not-inc  277783   Some-college   10             Divorced
# 25450  30            Private  176871   Some-college   10            Separated
# 28267  21            Private  209955        HS-grad    9        Never-married
# 25786  28            Private  251905    Prof-school   15        Never-married
# 15542  59            Private  153484      Bachelors   13   Married-civ-spouse
# 18403  19            Private  214678        HS-grad    9        Never-married
#
#              Adm-clerical   Not-in-family                White     Male  \
# ...

# %%
data.columns
# Out:
# Index(['39', ' State-gov', ' 77516', ' Bachelors', ' 13', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' 2174', ' 0',
#        ' 40', ' United-States', ' <=50K'],
#       dtype='object')

# %%
df1=data.copy()

# %%
df1.rename(columns={"39": "ID"}, inplace=True)

# %%
df1.head()
# Out:
#    ID          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
df1.rename(columns={"2174": "kids"}, inplace=True)

# %%
df1[' State-gov']
# Out:
# 0         Self-emp-not-inc
# 1                  Private
# 2                  Private
# 3                  Private
# 4                  Private
#                ...
# 32555              Private
# 32556              Private
# 32557              Private
# 32558              Private
# 32559         Self-emp-inc
# Name:  State-gov, Length: 32560, dtype: object

# %%
df1[' State-gov'].unique()
# Out:
# array([' Self-emp-not-inc', ' Private', ' State-gov', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
df1[' State-gov'].str.replace(' ?',' Without-pay')
# Out:
# C:\Users\PAVAN D\AppData\Local\Temp\ipykernel_11868\3167145865.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1[' State-gov'].str.replace(' ?',' Without-pay')
# 0         Without-pay Without-payS Without-paye Without...
# 1         Without-pay Without-payP Without-payr Without...
# 2         Without-pay Without-payP Without-payr Without...
# 3         Without-pay Without-payP Without-payr Without...
# 4         Without-pay Without-payP Without-payr Without...
#                                ...
# 32555     Without-pay Without-payP Without-payr Without...
# 32556     Without-pay Without-payP Without-payr Without...
# 32557     Without-pay Without-payP Without-payr Without...
# 32558     Without-pay Without-payP Without-payr Without...
# 32559     Without-pay Without-payS Without-paye Without...
# Name:  State-gov, Length: 32560, dtype: object

# %%
df1[' State-gov']
# Out:
# 0         Self-emp-not-inc
# 1                  Private
# 2                  Private
# 3                  Private
# 4                  Private
#                ...
# 32555              Private
# 32556              Private
# 32557              Private
# 32558              Private
# 32559         Self-emp-inc
# Name:  State-gov, Length: 32560, dtype: object

# %%
df1.columns
# Out:
# Index(['ID', ' State-gov', ' 77516', ' Bachelors', ' 13', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' 2174', ' 0',
#        ' 40', ' United-States', ' <=50K'],
#       dtype='object')

# %%
data[' Male']
# Out:
# 0           Male
# 1           Male
# 2           Male
# 3         Female
# 4         Female
#           ...
# 32555     Female
# 32556       Male
# 32557     Female
# 32558       Male
# 32559     Female
# Name:  Male, Length: 32560, dtype: object

# %%
 data[' Not-in-family'].head()
# Out:
# 0           Husband
# 1     Not-in-family
# 2           Husband
# 3              Wife
# 4              Wife
# Name:  Not-in-family, dtype: object

# %%
df1[' Not-in-family'].str.replace(' Not-in-family',"")
# Out:
# 0           Husband
# 1
# 2           Husband
# 3              Wife
# 4              Wife
#             ...
# 32555          Wife
# 32556       Husband
# 32557     Unmarried
# 32558     Own-child
# 32559          Wife
# Name:  Not-in-family, Length: 32560, dtype: object

# %%
df1.head()
# Out:
#    ID          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
df1[df1.duplicated(' State-gov')]
# Out:
#        ID          State-gov   77516    Bachelors   13  \
# 2      53            Private  234721         11th    7
# 3      28            Private  338409    Bachelors   13
# 4      37            Private  284582      Masters   14
# 5      49            Private  160187          9th    5
# 6      52   Self-emp-not-inc  209642      HS-grad    9
# ...    ..                ...     ...          ...  ...
# 32555  27            Private  257302   Assoc-acdm   12
# 32556  40            Private  154374      HS-grad    9
# 32557  58            Private  151910      HS-grad    9
# 32558  22            Private  201490      HS-grad    9
# 32559  52       Self-emp-inc  287927      HS-grad    9
#
#                 Never-married        Adm-clerical   Not-in-family   White  \
# 2          Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3          Married-civ-spouse      Prof-specialty            Wife   Black
# 4          Married-civ-spouse     Exec-managerial            Wife   White
# ...

# %%
categorical_features = [feature for feature in df1.columns if df1[feature].dtype == 'O']

# %%
categorical_features
# Out:
# [' State-gov',
#  ' Bachelors',
#  ' Never-married',
#  ' Adm-clerical',
#  ' Not-in-family',
#  ' White',
#  ' Male',
#  ' United-States',
#  ' <=50K']

# %%
df1.rename(columns={' 77516': "ID1",' 13':"ID2",' 2174':"ID3",' 0':"ID4",' 40':"ID5"}, inplace=True)

# %%
numeric_features = [feature for feature in df1.columns if df1[feature].dtype != 'O']

# %%
numeric_features
# Out:
# ['ID', 'ID1', 'ID2', 'ID3', 'ID4', 'ID5']

# %%
df1[numeric_features]
# Out:
#        ID     ID1  ID2    ID3  ID4  ID5
# 0      50   83311   13      0    0   13
# 1      38  215646    9      0    0   40
# 2      53  234721    7      0    0   40
# 3      28  338409   13      0    0   40
# 4      37  284582   14      0    0   40
# ...    ..     ...  ...    ...  ...  ...
# 32555  27  257302   12      0    0   38
# 32556  40  154374    9      0    0   40
# 32557  58  151910    9      0    0   40
# 32558  22  201490    9      0    0   20
# 32559  52  287927    9  15024    0   40
#
# [32560 rows x 6 columns]

# %%
df1[categorical_features]
# Out:
#                State-gov    Bachelors        Never-married  \
# 0       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 1                Private      HS-grad             Divorced
# 2                Private         11th   Married-civ-spouse
# 3                Private    Bachelors   Married-civ-spouse
# 4                Private      Masters   Married-civ-spouse
# ...                  ...          ...                  ...
# 32555            Private   Assoc-acdm   Married-civ-spouse
# 32556            Private      HS-grad   Married-civ-spouse
# 32557            Private      HS-grad              Widowed
# 32558            Private      HS-grad        Never-married
# 32559       Self-emp-inc      HS-grad   Married-civ-spouse
#
#              Adm-clerical   Not-in-family   White     Male   United-States  \
# 0         Exec-managerial         Husband   White     Male   United-States
# 1       Handlers-cleaners   Not-in-family   White     Male   United-States
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df1=df1.drop_duplicates(subset=[' State-gov'],keep='first')

# %%
df1[categorical_features]
# Out:
#               State-gov      Bachelors        Never-married  \
# 0      Self-emp-not-inc      Bachelors   Married-civ-spouse
# 1               Private        HS-grad             Divorced
# 10            State-gov      Bachelors   Married-civ-spouse
# 21          Federal-gov            9th   Married-civ-spouse
# 24            Local-gov      Bachelors   Married-civ-spouse
# 26                    ?   Some-college   Married-civ-spouse
# 53         Self-emp-inc        HS-grad             Divorced
# 1900        Without-pay        7th-8th              Widowed
# 5360       Never-worked           10th        Never-married
#
#             Adm-clerical   Not-in-family                White     Male  \
# 0        Exec-managerial         Husband                White     Male
# 1      Handlers-cleaners   Not-in-family                White     Male
# 10        Prof-specialty         Husband   Asian-Pac-Islander     Male
# 21       Farming-fishing         Husband                Black     Male
# ...

# %%
for col in categorical_features:
    print(f"{col}:{df1[col].value_counts(normalize=True)*100}")
    print("=============================================")
# Out:
#  State-gov: Self-emp-not-inc    11.111111
#  Private             11.111111
#  State-gov           11.111111
#  Federal-gov         11.111111
#  Local-gov           11.111111
#  ?                   11.111111
#  Self-emp-inc        11.111111
#  Without-pay         11.111111
#  Never-worked        11.111111
# Name:  State-gov, dtype: float64
# ...
#  Bachelors: Bachelors       33.333333
#  HS-grad         22.222222
#  9th             11.111111
#  Some-college    11.111111
#  7th-8th         11.111111
#  10th            11.111111
# Name:  Bachelors, dtype: float64
# ...
#  Never-married: Married-civ-spouse    55.555556
#  Divorced              22.222222
#  Widowed               11.111111
#  Never-married         11.111111
# Name:  Never-married, dtype: float64
# ...
#  Adm-clerical: Exec-managerial      22.222222
#  Farming-fishing      22.222222
#  ?                    22.222222
#  Handlers-cleaners    11.111111
#  Prof-specialty       11.111111
#  Tech-support         11.111111
# ...

# %%
sns.countplot(x=df1[' Bachelors'])
# Out:
# <AxesSubplot:xlabel=' Bachelors', ylabel='count'>

# %%
sns.countplot(x=df1[" Not-in-family"])
# Out:
# <AxesSubplot:xlabel=' Not-in-family', ylabel='count'>

# %%
# categorical columns
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
category = [ ' Bachelors', ' Not-in-family']
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=df1[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
numeric_features
# Out:
# ['ID', 'ID1', 'ID2', 'ID3', 'ID4', 'ID5']

# %%
sns.kdeplot(df1['ID1'])
# Out:
# <AxesSubplot:xlabel='ID1', ylabel='Density'>

# %%
sns.kdeplot(df1['ID'])
# Out:
# <AxesSubplot:xlabel='ID', ylabel='Density'>

# %%
sns.distplot(df1['ID'])
# Out:
# <AxesSubplot:xlabel='ID', ylabel='Density'>

# %%
plt.hist(df1["ID"])
plt.show()

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numeric_features)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=df1[numeric_features[i]],shade=True, color='r')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %%
plt.hist(df1['ID2'])
# Out:
# (array([1., 1., 1., 0., 0., 2., 1., 0., 0., 3.]),
#  array([ 4. ,  4.9,  5.8,  6.7,  7.6,  8.5,  9.4, 10.3, 11.2, 12.1, 13. ]),
#  <BarContainer object of 10 artists>)

# %%
df1.head()
# Out:
#     ID          State-gov     ID1   Bachelors  ID2        Never-married  \
# 0   50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1   38            Private  215646     HS-grad    9             Divorced
# 10  30          State-gov  141297   Bachelors   13   Married-civ-spouse
# 21  35        Federal-gov   76845         9th    5   Married-civ-spouse
# 24  56          Local-gov  216851   Bachelors   13   Married-civ-spouse
#
#           Adm-clerical   Not-in-family                White   Male  ID3  ID4  \
# 0      Exec-managerial         Husband                White   Male    0    0
# 1    Handlers-cleaners   Not-in-family                White   Male    0    0
# 10      Prof-specialty         Husband   Asian-Pac-Islander   Male    0    0
# 21     Farming-fishing         Husband                Black   Male    0    0
# 24        Tech-support         Husband                White   Male    0    0
#
#     ID5   United-States   <=50K
# 0    13   United-States   <=50K
# ...

# %%
univariate analysis
most popularity in State-gov

# %%
df1[" State-gov"].value_counts().plot.pie(y=df1[" State-gov"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel=' State-gov'>

# %%
df_cat=df1[" Bachelors"].value_counts()[:10]

# %%
Bachelors= pd.DataFrame(df1[" Bachelors"].value_counts())        #Dataframe of apps on the basis of category
Bachelors.rename(columns = {" Bachelors":'Count'},inplace=True)

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df_cat, y ='Count',data = Bachelors[:10],palette='hls')
plt.title('Top 10 App categories')
plt.xticks(rotation=90)
plt.show()

# %%
df1.head()
# Out:
#     ID          State-gov     ID1   Bachelors  ID2        Never-married  \
# 0   50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1   38            Private  215646     HS-grad    9             Divorced
# 10  30          State-gov  141297   Bachelors   13   Married-civ-spouse
# 21  35        Federal-gov   76845         9th    5   Married-civ-spouse
# 24  56          Local-gov  216851   Bachelors   13   Married-civ-spouse
#
#           Adm-clerical   Not-in-family                White   Male  ID3  ID4  \
# 0      Exec-managerial         Husband                White   Male    0    0
# 1    Handlers-cleaners   Not-in-family                White   Male    0    0
# 10      Prof-specialty         Husband   Asian-Pac-Islander   Male    0    0
# 21     Farming-fishing         Husband                Black   Male    0    0
# 24        Tech-support         Husband                White   Male    0    0
#
#     ID5   United-States   <=50K
# 0    13   United-States   <=50K
# ...

# %%
df_cat_installs=df1.groupby([' State-gov'])[' Never-married'].sum().sort_values(ascending=False).reset_index()

# %%
df2=df_cat_installs.head(10)

# %%
df2
# Out:
#            State-gov        Never-married
# 0        Without-pay              Widowed
# 1       Never-worked        Never-married
# 2                  ?   Married-civ-spouse
# 3        Federal-gov   Married-civ-spouse
# 4          Local-gov   Married-civ-spouse
# 5   Self-emp-not-inc   Married-civ-spouse
# 6          State-gov   Married-civ-spouse
# 7            Private             Divorced
# 8       Self-emp-inc             Divorced
