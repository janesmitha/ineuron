# %%
import pandas as pd
df=pd.read_csv('C:/Users/PAVAN D/Downloads/Training Dataset.csv')

# %%
from scipy.io import arff
import pandas as pd
data=arff.loadarff('C:/Users/PAVAN D/Downloads/Training Dataset.arff')
df=pd.DataFrame(data[0])
df.head()
# Out:
#   having_IP_Address URL_Length Shortining_Service having_At_Symbol  \
# 0             b'-1'       b'1'               b'1'             b'1'
# 1              b'1'       b'1'               b'1'             b'1'
# 2              b'1'       b'0'               b'1'             b'1'
# 3              b'1'       b'0'               b'1'             b'1'
# 4              b'1'       b'0'              b'-1'             b'1'
#
#   double_slash_redirecting Prefix_Suffix having_Sub_Domain SSLfinal_State  \
# 0                    b'-1'         b'-1'             b'-1'          b'-1'
# 1                     b'1'         b'-1'              b'0'           b'1'
# 2                     b'1'         b'-1'             b'-1'          b'-1'
# 3                     b'1'         b'-1'             b'-1'          b'-1'
# 4                     b'1'         b'-1'              b'1'           b'1'
#
#   Domain_registeration_length Favicon  ... popUpWidnow Iframe age_of_domain  \
# ...

# %%
#importing basic packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#   having_IP_Address URL_Length Shortining_Service having_At_Symbol  \
# 0             b'-1'       b'1'               b'1'             b'1'
# 1              b'1'       b'1'               b'1'             b'1'
# 2              b'1'       b'0'               b'1'             b'1'
# 3              b'1'       b'0'               b'1'             b'1'
# 4              b'1'       b'0'              b'-1'             b'1'
#
#   double_slash_redirecting Prefix_Suffix having_Sub_Domain SSLfinal_State  \
# 0                    b'-1'         b'-1'             b'-1'          b'-1'
# 1                     b'1'         b'-1'              b'0'           b'1'
# 2                     b'1'         b'-1'             b'-1'          b'-1'
# 3                     b'1'         b'-1'             b'-1'          b'-1'
# 4                     b'1'         b'-1'              b'1'           b'1'
#
#   Domain_registeration_length Favicon  ... popUpWidnow Iframe age_of_domain  \
# ...

# %%
df.tail()
# Out:
#       having_IP_Address URL_Length Shortining_Service having_At_Symbol  \
# 11050              b'1'      b'-1'               b'1'            b'-1'
# 11051             b'-1'       b'1'               b'1'            b'-1'
# 11052              b'1'      b'-1'               b'1'             b'1'
# 11053             b'-1'      b'-1'               b'1'             b'1'
# 11054             b'-1'      b'-1'               b'1'             b'1'
#
#       double_slash_redirecting Prefix_Suffix having_Sub_Domain SSLfinal_State  \
# 11050                     b'1'          b'1'              b'1'           b'1'
# 11051                    b'-1'         b'-1'              b'1'          b'-1'
# 11052                     b'1'         b'-1'              b'1'          b'-1'
# 11053                     b'1'         b'-1'             b'-1'          b'-1'
# 11054                     b'1'         b'-1'             b'-1'          b'-1'
#
#       Domain_registeration_length Favicon  ... popUpWidnow Iframe  \
# ...

# %%
df.shape
# Out:
# (11055, 31)

# %%
df.sample(10)
# Out:
#       having_IP_Address URL_Length Shortining_Service having_At_Symbol  \
# 7237              b'-1'       b'1'              b'-1'             b'1'
# 369                b'1'      b'-1'               b'1'             b'1'
# 8591               b'1'       b'1'               b'1'            b'-1'
# 2098               b'1'      b'-1'               b'1'             b'1'
# 4239               b'1'      b'-1'               b'1'             b'1'
# 6                  b'1'       b'0'              b'-1'             b'1'
# 9045               b'1'       b'1'               b'1'            b'-1'
# 10467             b'-1'      b'-1'               b'1'             b'1'
# 2764               b'1'      b'-1'               b'1'             b'1'
# 5433              b'-1'      b'-1'               b'1'             b'1'
#
#       double_slash_redirecting Prefix_Suffix having_Sub_Domain SSLfinal_State  \
# 7237                     b'-1'         b'-1'              b'1'           b'1'
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11055 entries, 0 to 11054
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   having_IP_Address            11055 non-null  object
#  1   URL_Length                   11055 non-null  object
#  2   Shortining_Service           11055 non-null  object
#  3   having_At_Symbol             11055 non-null  object
#  4   double_slash_redirecting     11055 non-null  object
#  5   Prefix_Suffix                11055 non-null  object
#  6   having_Sub_Domain            11055 non-null  object
#  7   SSLfinal_State               11055 non-null  object
#  8   Domain_registeration_length  11055 non-null  object
#  9   Favicon                      11055 non-null  object
#  10  port                         11055 non-null  object
#  11  HTTPS_token                  11055 non-null  object
#  12  Request_URL                  11055 non-null  object
# ...

# %%
df.describe(include='all').T
# Out:
#                              count unique    top   freq
# having_IP_Address            11055      2   b'1'   7262
# URL_Length                   11055      3  b'-1'   8960
# Shortining_Service           11055      2   b'1'   9611
# having_At_Symbol             11055      2   b'1'   9400
# double_slash_redirecting     11055      2   b'1'   9626
# Prefix_Suffix                11055      2  b'-1'   9590
# having_Sub_Domain            11055      3   b'1'   4070
# SSLfinal_State               11055      3   b'1'   6331
# Domain_registeration_length  11055      2  b'-1'   7389
# Favicon                      11055      2   b'1'   9002
# port                         11055      2   b'1'   9553
# HTTPS_token                  11055      2   b'1'   9259
# Request_URL                  11055      2   b'1'   6560
# URL_of_Anchor                11055      3   b'0'   5337
# Links_in_tags                11055      3   b'0'   4449
# SFH                          11055      3  b'-1'   8440
# ...

# %%
df[df.duplicated()]
# Out:
#       having_IP_Address URL_Length Shortining_Service having_At_Symbol  \
# 180                b'1'      b'-1'               b'1'             b'1'
# 203                b'1'      b'-1'               b'1'             b'1'
# 323                b'1'      b'-1'               b'1'             b'1'
# 364                b'1'      b'-1'               b'1'             b'1'
# 381                b'1'      b'-1'               b'1'             b'1'
# ...                 ...        ...                ...              ...
# 11047             b'-1'      b'-1'               b'1'             b'1'
# 11050              b'1'      b'-1'               b'1'            b'-1'
# 11051             b'-1'       b'1'               b'1'            b'-1'
# 11052              b'1'      b'-1'               b'1'             b'1'
# 11053             b'-1'      b'-1'               b'1'             b'1'
#
#       double_slash_redirecting Prefix_Suffix having_Sub_Domain SSLfinal_State  \
# ...

# %%
df['URL_Length'].shape
# Out:
# (11055,)

# %%
df['having_IP_Address'].shape
# Out:
# (11055,)

# %%
df['having_IP_Address'].head(20)
# Out:
# 0     b'-1'
# 1      b'1'
# 2      b'1'
# 3      b'1'
# 4      b'1'
# 5     b'-1'
# 6      b'1'
# 7      b'1'
# 8      b'1'
# 9      b'1'
# 10     b'1'
# 11     b'1'
# 12    b'-1'
# 13     b'1'
# 14     b'1'
# 15     b'1'
# 16     b'1'
# 17     b'1'
# 18     b'1'
# 19     b'1'
# Name: having_IP_Address, dtype: object

# %%
df1=df.copy()

# %%
df1.head()
# Out:
#   having_IP_Address URL_Length Shortining_Service having_At_Symbol  \
# 0             b'-1'       b'1'               b'1'             b'1'
# 1              b'1'       b'1'               b'1'             b'1'
# 2              b'1'       b'0'               b'1'             b'1'
# 3              b'1'       b'0'               b'1'             b'1'
# 4              b'1'       b'0'              b'-1'             b'1'
#
#   double_slash_redirecting Prefix_Suffix having_Sub_Domain SSLfinal_State  \
# 0                    b'-1'         b'-1'             b'-1'          b'-1'
# 1                     b'1'         b'-1'              b'0'           b'1'
# 2                     b'1'         b'-1'             b'-1'          b'-1'
# 3                     b'1'         b'-1'             b'-1'          b'-1'
# 4                     b'1'         b'-1'              b'1'           b'1'
#
#   Domain_registeration_length Favicon  ... popUpWidnow Iframe age_of_domain  \
# ...

# %%
df1['having_IP_Address'].dtype
# Out:
# dtype('O')

# %%
df1['having_IP_Address'].unique
# Out:
# <bound method Series.unique of 0        b'-1'
# 1         b'1'
# 2         b'1'
# 3         b'1'
# 4         b'1'
#          ...
# 11050     b'1'
# 11051    b'-1'
# 11052     b'1'
# 11053    b'-1'
# 11054    b'-1'
# Name: having_IP_Address, Length: 11055, dtype: object>

# %%
df1['having_IP_Address']=df['having_IP_Address'].replace("b'1'","1")

# %%
df1['having_IP_Address']=df['having_IP_Address'].replace("b'-1'","-1")

# %%
df1['having_IP_Address'].unique()
# Out:
# array([b'-1', b'1'], dtype=object)

# %%
df1['URL_Length'].head(20)
# Out:
# 0      b'1'
# 1      b'1'
# 2      b'0'
# 3      b'0'
# 4      b'0'
# 5      b'0'
# 6      b'0'
# 7      b'0'
# 8      b'0'
# 9      b'1'
# 10     b'1'
# 11     b'1'
# 12     b'1'
# 13     b'1'
# 14     b'1'
# 15    b'-1'
# 16    b'-1'
# 17    b'-1'
# 18     b'1'
# 19     b'1'
# Name: URL_Length, dtype: object

# %%
df1['URL_Length'].dtype
# Out:
# dtype('O')

# %%
df1['having_IP_Address'].dtype
# Out:
# dtype('O')

# %%
df1['having_IP_Address']=df1['having_IP_Address'].astype('int')

# %%
df1['having_IP_Address'].dtype
# Out:
# dtype('int32')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11055 entries, 0 to 11054
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   having_IP_Address            11055 non-null  int32
#  1   URL_Length                   11055 non-null  object
#  2   Shortining_Service           11055 non-null  object
#  3   having_At_Symbol             11055 non-null  object
#  4   double_slash_redirecting     11055 non-null  object
#  5   Prefix_Suffix                11055 non-null  object
#  6   having_Sub_Domain            11055 non-null  object
#  7   SSLfinal_State               11055 non-null  object
#  8   Domain_registeration_length  11055 non-null  object
#  9   Favicon                      11055 non-null  object
#  10  port                         11055 non-null  object
#  11  HTTPS_token                  11055 non-null  object
#  12  Request_URL                  11055 non-null  object
# ...

# %%
df1['having_IP_Address']=df['having_IP_Address'].replace("b'1'","1")

# %%
df1['having_IP_Address'].head()
# Out:
# 0    b'-1'
# 1     b'1'
# 2     b'1'
# 3     b'1'
# 4     b'1'
# Name: having_IP_Address, dtype: object

# %%
df[~df.URL_Length.isnumeric()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6920\1163602608.py in <module>
# ----> 1 df[~df.URL_Length.isnumeric()]
#
# C:\ineuron\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'isnumeric'

# %%
You can see that there are no missing values in the Dataset

# %%
for col in df1.columns:
    unique_value_list = df1[col].unique()
    if len(unique_value_list) > 10:
        print(f'{col} has {df1[col].nunique()} unique values')
    else:
        print(f'{col} contains:\t\t\t{unique_value_list}')
# Out:
# having_IP_Address contains:			[b'-1' b'1']
# URL_Length contains:			[b'1' b'0' b'-1']
# Shortining_Service contains:			[b'1' b'-1']
# having_At_Symbol contains:			[b'1' b'-1']
# double_slash_redirecting contains:			[b'-1' b'1']
# Prefix_Suffix contains:			[b'-1' b'1']
# having_Sub_Domain contains:			[b'-1' b'0' b'1']
# SSLfinal_State contains:			[b'-1' b'1' b'0']
# Domain_registeration_length contains:			[b'-1' b'1']
# Favicon contains:			[b'1' b'-1']
# port contains:			[b'1' b'-1']
# HTTPS_token contains:			[b'-1' b'1']
# Request_URL contains:			[b'1' b'-1']
# URL_of_Anchor contains:			[b'-1' b'0' b'1']
# Links_in_tags contains:			[b'1' b'-1' b'0']
# SFH contains:			[b'-1' b'1' b'0']
# Submitting_to_email contains:			[b'-1' b'1']
# Abnormal_URL contains:			[b'-1' b'1']
# Redirect contains:			[b'0' b'1']
# on_mouseover contains:			[b'1' b'-1']
# RightClick contains:			[b'1' b'-1']
# popUpWidnow contains:			[b'1' b'-1']
# Iframe contains:			[b'1' b'-1']
# ...

# %%
df1["Result"].unique()
# Out:
# array([b'-1', b'1'], dtype=object)

# %%
for i in df1.columns:
    if url not in i:
        data_copy.drop(i,axis=l,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6920\4052466686.py in <module>
#       1 for i in df1.columns:
# ----> 2     if url not in i:
#       3         data_copy.drop(i,axis=l,inplace=True)
#
# NameError: name 'url' is not defined

# %%
df1.columns
# Out:
# Index(['having_IP_Address', 'URL_Length', 'Shortining_Service',
#        'having_At_Symbol', 'double_slash_redirecting', 'Prefix_Suffix',
#        'having_Sub_Domain', 'SSLfinal_State', 'Domain_registeration_length',
#        'Favicon', 'port', 'HTTPS_token', 'Request_URL', 'URL_of_Anchor',
#        'Links_in_tags', 'SFH', 'Submitting_to_email', 'Abnormal_URL',
#        'Redirect', 'on_mouseover', 'RightClick', 'popUpWidnow', 'Iframe',
#        'age_of_domain', 'DNSRecord', 'web_traffic', 'Page_Rank',
#        'Google_Index', 'Links_pointing_to_page', 'Statistical_report',
#        'Result'],
#       dtype='object')

# %%
for i in df1.columns:
    if url not in i:
        df1.drop(i,axis=l,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6920\2745341855.py in <module>
#       1 for i in df1.columns:
# ----> 2     if url not in i:
#       3         df1.drop(i,axis=l,inplace=True)
#
# NameError: name 'url' is not defined

# %%
print(df1['Result'].value_counts())
sns.countplot(df1['Result'])
# Out:
# b'1'     6157
# b'-1'    4898
# Name: Result, dtype: int64
# C:\ineuron\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Result', ylabel='count'>

# %%
The data seems pretty much balanced i.e. There is not a significant difference between the count of the target variable values.

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df1.corr(), linewidths=.5)
# Out:
# <AxesSubplot:>

# %%
Note that feature popUpWindow and favicon are highly correlated. Looking at the definitions of these features from the Data description, we can say that, for websites where favicon is loaded from external links the pop-up window mostly contains text field. This is said just by seeing the high correlation. Dropping one of the features or not is an experimental decision.

Note that some features are negatively correlated but the color index minimum correlation is upto -0.6. Negative correlations are where one feature marks it as phishing and other don't.

# %%
df1['Result'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df1.head(2)
# Out:
#   having_IP_Address URL_Length Shortining_Service having_At_Symbol  \
# 0             b'-1'       b'1'               b'1'             b'1'
# 1              b'1'       b'1'               b'1'             b'1'
#
#   double_slash_redirecting Prefix_Suffix having_Sub_Domain SSLfinal_State  \
# 0                    b'-1'         b'-1'             b'-1'          b'-1'
# 1                     b'1'         b'-1'              b'0'           b'1'
#
#   Domain_registeration_length Favicon  ... popUpWidnow Iframe age_of_domain  \
# 0                       b'-1'    b'1'  ...        b'1'   b'1'         b'-1'
# 1                       b'-1'    b'1'  ...        b'1'   b'1'         b'-1'
#
#   DNSRecord web_traffic Page_Rank Google_Index Links_pointing_to_page  \
# 0     b'-1'       b'-1'     b'-1'         b'1'                   b'1'
# 1     b'-1'        b'0'     b'-1'         b'1'                   b'1'
#
#   Statistical_report Result
# 0              b'-1'  b'-1'
# 1               b'1'  b'-1'
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11055 entries, 0 to 11054
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   having_IP_Address            11055 non-null  object
#  1   URL_Length                   11055 non-null  object
#  2   Shortining_Service           11055 non-null  object
#  3   having_At_Symbol             11055 non-null  object
#  4   double_slash_redirecting     11055 non-null  object
#  5   Prefix_Suffix                11055 non-null  object
#  6   having_Sub_Domain            11055 non-null  object
#  7   SSLfinal_State               11055 non-null  object
#  8   Domain_registeration_length  11055 non-null  object
#  9   Favicon                      11055 non-null  object
#  10  port                         11055 non-null  object
#  11  HTTPS_token                  11055 non-null  object
#  12  Request_URL                  11055 non-null  object
# ...

# %%
df1['age_of_domain']
# Out:
# 0        b'-1'
# 1        b'-1'
# 2         b'1'
# 3        b'-1'
# 4        b'-1'
#          ...
# 11050     b'1'
# 11051     b'1'
# 11052     b'1'
# 11053     b'1'
# 11054    b'-1'
# Name: age_of_domain, Length: 11055, dtype: object

# %%
df1['age_of_domain'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 11055 entries, 0 to 11054
# Series name: age_of_domain
# Non-Null Count  Dtype
# --------------  -----
# 11055 non-null  object
# dtypes: object(1)
# memory usage: 86.5+ KB

# %%
df1['having_IP_Address'].dtype
# Out:
# dtype('O')

# %%
df1['having_IP_Address'].head()
# Out:
# 0    b'-1'
# 1     b'1'
# 2     b'1'
# 3     b'1'
# 4     b'1'
# Name: having_IP_Address, dtype: object

# %%
df1['having_IP_Address'].unique()
# Out:
# array([b'-1', b'1'], dtype=object)

# %%
df1["having_IP_Address"]=df1["having_IP_Address"].astype("float")

# %%
df1["having_IP_Address"].dtype
# Out:
# dtype('float64')

# %%
df1["having_IP_Address"].head()
# Out:
# 0   -1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: having_IP_Address, dtype: float64

# %%
df1["having_IP_Address"][0]
# Out:
# -1.0

# %%
df1["having_IP_Address"][2]
# Out:
# 1.0

# %%
df1["having_IP_Address"].unique()
# Out:
# array([-1.,  1.])

# %%
sns.kdeplot(df1["having_IP_Address"])
# Out:
# <AxesSubplot:xlabel='having_IP_Address', ylabel='Density'>

# %%
plt.hist(df1["double_slash_redirecting"])
plt.show()

# %%
df1["having_IP_Address"].value_counts().plot.pie(y=df1["having_IP_Address"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='having_IP_Address'>

# %%
df_cat=df1["having_IP_Address"].value_counts()[:10]

# %%
df_cat
# Out:
# Series([], Name: having_IP_Address, dtype: int64)

# %%
having_IP_Address = pd.DataFrame(df1['having_IP_Address'].value_counts())        #Dataframe of apps on the basis of category
having_IP_Address.rename(columns = {'having_IP_Address':'Count'},inplace=True)
